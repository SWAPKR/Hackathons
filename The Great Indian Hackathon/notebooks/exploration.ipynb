# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('../input/train.csv')
test=pd.read_csv('../input/test.csv')

# %%
train.head()
# Out:
#    InvoiceNo  StockCode  Description  Quantity          InvoiceDate  \
# 0       6141       1583          144         3  2011-05-06 16:54:00
# 1       6349       1300         3682         6  2011-05-11 07:35:00
# 2      16783       2178         1939         4  2011-11-20 13:20:00
# 3      16971       2115         2983         1  2011-11-22 12:07:00
# 4       6080       1210         2886        12  2011-05-06 09:00:00
#
#    UnitPrice  CustomerID  Country
# 0       3.75     14056.0       35
# 1       1.95     13098.0       35
# 2       5.95     15044.0       35
# 3       0.83     15525.0       35
# 4       1.65     13952.0       35

# %%
# print(data.info())
# print(data.describe())
# print(train.info())
# print(train.describe())
# print(test.info())
# print(test.describe())

# %%
train['StockCode']=train['StockCode'].astype(str) + '_' + train['Description'].astype(str)
test['StockCode']=test['StockCode'].astype(str) + '_' + test['Description'].astype(str)

# %%
train['InvoiceDate']=pd.to_datetime(train['InvoiceDate'])
test['InvoiceDate']=pd.to_datetime(test['InvoiceDate'])

# %%
train.loc[:,'year']=train['InvoiceDate'].dt.year
train.loc[:,'months']=train['InvoiceDate'].dt.month
train.loc[:,'day']=train['InvoiceDate'].dt.dayofweek
train.loc[:,'hour']=train['InvoiceDate'].dt.hour
train.drop('InvoiceDate',inplace=True,axis=1)

# %%
test.loc[:,'year']=test['InvoiceDate'].dt.year
test.loc[:,'months']=test['InvoiceDate'].dt.month
test.loc[:,'day']=test['InvoiceDate'].dt.dayofweek
test.loc[:,'hour']=test['InvoiceDate'].dt.hour
test.drop('InvoiceDate',inplace=True,axis=1)

# %%
train[train['UnitPrice']>5000]
# Out:
#         InvoiceNo  StockCode  Description  Quantity  UnitPrice  CustomerID  \
# 140723      20237  3681_2140         2140        -1   38970.00     15098.0
# 239556      19848  3683_2624         2624        -1    8142.75     16029.0
#
#         Country  year  months  day  hour
# 140723       35  2011       6    4    15
# 239556       35  2011       5    1    12

# %%
train.drop(index=[140723,239556],inplace=True,axis=0)
train.drop('Description',axis=1,inplace=True)
test.drop('Description',axis=1,inplace=True)

# %%
# plt.figure()
# print('skew %.2f' %train['UnitPrice'].skew())
# sns.distplot(train['UnitPrice']);

# %%
# train['UnitPrice']=train['UnitPrice'].map(lambda i:np.log(i) if i>0 else 0)

# %%
# plt.figure()
# print('skew %.2f' %train['UnitPrice'].skew())
# sns.distplot(train['UnitPrice']);

# %%
train.head()
# Out:
#    InvoiceNo  StockCode  Quantity  UnitPrice  CustomerID  Country  year  \
# 0       6141   1583_144         3       3.75     14056.0       35  2011
# 1       6349  1300_3682         6       1.95     13098.0       35  2011
# 2      16783  2178_1939         4       5.95     15044.0       35  2011
# 3      16971  2115_2983         1       0.83     15525.0       35  2011
# 4       6080  1210_2886        12       1.65     13952.0       35  2011
#
#    months  day  hour
# 0       5    4    16
# 1       5    2     7
# 2      11    6    13
# 3      11    1    12
# 4       5    4     9

# %%
test.head()
# Out:
#    InvoiceNo  StockCode  Quantity  CustomerID  Country  year  months  day  \
# 0       3139  1709_1079         3     16161.0       35  2011       2    1
# 1        617   510_3457         1     17341.0       35  2010      12    2
# 2      14653    604_694        36     15158.0       35  2011      10    1
# 3       8634  1478_3473         2     16033.0       35  2011       6    0
# 4      15546   3216_871         1     15351.0       35  2011      11    6
#
#    hour
# 0    15
# 1    12
# 2    13
# 3    12
# 4    16

# %%
test['UnitPrice']=-100

# %%
data=pd.concat((train,test)).reset_index(drop=True)

# %%
data.head()
# Out:
#    InvoiceNo  StockCode  Quantity  UnitPrice  CustomerID  Country  year  \
# 0       6141   1583_144         3       3.75     14056.0       35  2011
# 1       6349  1300_3682         6       1.95     13098.0       35  2011
# 2      16783  2178_1939         4       5.95     15044.0       35  2011
# 3      16971  2115_2983         1       0.83     15525.0       35  2011
# 4       6080  1210_2886        12       1.65     13952.0       35  2011
#
#    months  day  hour
# 0       5    4    16
# 1       5    2     7
# 2      11    6    13
# 3      11    1    12
# 4       5    4     9

# %%
temp1=data['InvoiceNo'].value_counts().to_dict()
data['frq_inv']=data['InvoiceNo']
data['frq_inv']=data['frq_inv'].map(temp1)

# %%
temp2=data['CustomerID'].value_counts().to_dict()
data['frq_custo']=data['CustomerID']
data['frq_custo']=data['frq_custo'].map(temp2)

# %%
temp3=data['StockCode'].value_counts().to_dict()
data['frq_stock']=data['StockCode']
data['frq_stock']=data['frq_stock'].map(temp3)

# %%
data.head()
# Out:
#    InvoiceNo  StockCode  Quantity  UnitPrice  CustomerID  Country  year  \
# 0       6141   1583_144         3       3.75     14056.0       35  2011
# 1       6349  1300_3682         6       1.95     13098.0       35  2011
# 2      16783  2178_1939         4       5.95     15044.0       35  2011
# 3      16971  2115_2983         1       0.83     15525.0       35  2011
# 4       6080  1210_2886        12       1.65     13952.0       35  2011
#
#    months  day  hour  frq_inv  frq_custo  frq_stock
# 0       5    4    16       44       1128        491
# 1       5    2     7       42        605        282
# 2      11    6    13       66        461        475
# 3      11    1    12       40        180        480
# 4       5    4     9       44        138        156

# %%
test_upd=data[data['UnitPrice']==-100]
train_upd=data[data['UnitPrice']!=-100]

# %%
train_upd.to_csv('../input/train_upd.csv',index=False)
test_upd.to_csv('../input/test_upd.csv',index=False)

# %%
train_upd.head()
# Out:
#    InvoiceNo  StockCode  Quantity  UnitPrice  CustomerID  Country  year  \
# 0       6141   1583_144         3       3.75     14056.0       35  2011
# 1       6349  1300_3682         6       1.95     13098.0       35  2011
# 2      16783  2178_1939         4       5.95     15044.0       35  2011
# 3      16971  2115_2983         1       0.83     15525.0       35  2011
# 4       6080  1210_2886        12       1.65     13952.0       35  2011
#
#    months  day  hour  frq_inv  frq_custo  frq_stock
# 0       5    4    16       44       1128        491
# 1       5    2     7       42        605        282
# 2      11    6    13       66        461        475
# 3      11    1    12       40        180        480
# 4       5    4     9       44        138        156

# %%
sum(train_upd.UnitPrice>10)
# Out:
# 8194

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation, Reshape, Embedding,Concatenate,SpatialDropout1D,BatchNormalization

import pandas as pd 
from keras.models import Model
from keras.layers import Input, Dense, Concatenate, Reshape, Dropout
from keras.layers.embeddings import Embedding
import numpy as np
from sklearn.model_selection import StratifiedKFold
from  sklearn.utils import shuffle 
from sklearn.model_selection import train_test_split
from keras.models import model_from_json

from keras.models import load_model
from keras.callbacks import ModelCheckpoint
import keras.objectives
from keras.callbacks import CSVLogger

# %%
import pandas as pd
from sklearn import preprocessing
# read training data
train = pd.read_csv("../input/train_upd.csv")
test = pd.read_csv("../input/test_upd.csv")

# %%
train.head()
# Out:
#    InvoiceNo  StockCode  Quantity  UnitPrice  CustomerID  Country  year  \
# 0       6141   1583_144         3       3.75     14056.0       35  2011
# 1       6349  1300_3682         6       1.95     13098.0       35  2011
# 2      16783  2178_1939         4       5.95     15044.0       35  2011
# 3      16971  2115_2983         1       0.83     15525.0       35  2011
# 4       6080  1210_2886        12       1.65     13952.0       35  2011
#
#    months  day  hour  frq_inv  frq_custo  frq_stock
# 0       5    4    16       44       1128        491
# 1       5    2     7       42        605        282
# 2      11    6    13       66        461        475
# 3      11    1    12       40        180        480
# 4       5    4     9       44        138        156

# %%
# concatenate both training and test data
data = pd.concat([train, test]).reset_index(drop=True)
cat_col=[feat for feat in train.columns if feat not in ['UnitPrice']]

# %%
# for feat in cat_col:
#     if feat !='Quantity':
#         data.loc[data[feat].map(data[feat].value_counts())<5,feat]='rare'

# %%
# for feat in cat_col:
#     print(data[feat].value_counts())

# %%
for feat in cat_col:
    lbl_enc = preprocessing.LabelEncoder()
    temp_col = data[feat].fillna("NONE").astype(str).values
    data.loc[:, feat] = lbl_enc.fit_transform(temp_col)
train2= data[data.UnitPrice != -100].reset_index(drop=True)
test2 = data[data.UnitPrice == -100].reset_index(drop=True)

# %%
# from sklearn.model_selection import KFold
# train2['kfold']=-1

# kf=KFold(n_splits=10,shuffle=True,random_state=42)
# for fold,(trn,vld) in enumerate(kf.split(train2)):
#     train2.loc[vld,'kfold']=fold

# %%
train2.head()
# Out:
#    InvoiceNo  StockCode  Quantity  UnitPrice  CustomerID  Country  year  \
# 0      17903        671       271       3.75        1273       29     1
# 1      18133        351       358       1.95         576       29     1
# 2       7539       1447       305       5.95        1984       29     1
# 3       7748       1372       134       0.83        2351       29     1
# 4      17835        248       156       1.65        1195       29     1
#
#    months  day  hour  frq_inv  frq_custo  frq_stock
# 0       7    4     6      134         20        373
# 1       7    2    12      130        400        211
# 2       2    5     3      162        340        361
# 3       2    1     2      128        104        366
# 4       7    4    14      134         53         73

# %%
# def kfold(fold):
#     train_f=train2[train2['kfold']!=fold]
#     valid_f=train2[train2['kfold']==fold]
#     x_train=train_f.drop('UnitPrice',axis=1)
#     y_train=train_f['UnitPrice']
#     x_valid=valid_f.drop('UnitPrice',axis=1)
#     y_valid=valid_f['UnitPrice']
#     x_train.drop('kfold',axis=1,inplace=True)
#     x_valid.drop('kfold',axis=1,inplace=True)
#     return x_train,y_train,x_valid,y_valid
# # x_train,y_train,x_valid,y_valid=kfold(0)

# %%
# x_train,y_train,x_valid,y_valid=kfold(0)
# x_train.head()

# %%
data.Quantity.nunique()
# Out:
# 436

# %%
x_train=train2.drop('UnitPrice',axis=1)
y_train=train2['UnitPrice']

# %%
# fold=0
# x_train,y_train,x_valid,y_valid=kfold(fold)

x_trn=[]
for feat in cat_col:
    x_trn.append(x_train[feat].values)
    
# x_vld=[]
# for feat in cat_col:
#     x_vld.append(x_valid[feat].values)
    
x_tst=[]
for feat in cat_col:
    x_tst.append(test2[feat].values)  
    
inp_size={}
emb_size={}
for feat in cat_col:
    inp_size[feat]=data[feat].nunique()
    
for feat in cat_col:
    emb_size[feat]= int(min(50,np.ceil(inp_size[feat]/2)))

# %%
emb_size
# Out:
# {'InvoiceNo': 50,
#  'StockCode': 50,
#  'Quantity': 50,
#  'CustomerID': 50,
#  'Country': 19,
#  'year': 1,
#  'months': 6,
#  'day': 3,
#  'hour': 8,
#  'frq_inv': 50,
#  'frq_custo': 50,
#  'frq_stock': 50}

# %%
tensorboard_cb = keras.callbacks.TensorBoard(
    log_dir='tensorboard!',
    histogram_freq=1,
    write_graph=True,
    write_images=True
)
csv_logger = CSVLogger('history/loss!.csv', append=True, separator=',')

# %%
inputs = []
embeddings = []


for feat in cat_col:
    input1 = Input(shape=(1,))
    embedding = Embedding(inp_size[feat] +1 , emb_size[feat], input_length=1)(input1)
    embedding=SpatialDropout1D(0.3)(embedding)
    embedding = Reshape(target_shape=(emb_size[feat],))(embedding)
    inputs.append(input1)
    embeddings.append(embedding)
print(embeddings)

x = Concatenate()(embeddings)
# x = Dense(1024, activation='relu')(x)
# x = Dropout(.35)(x)
x = BatchNormalization()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(.35)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(.15)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(.15)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(.15)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(.15)(x)
x = Dense(16, activation='relu')(x)
x = Dropout(.15)(x)
output = Dense(1, activation='linear')(x)
model = Model(inputs, output)
# model = Model(inputs, output)


from keras import backend as K

# def root_mean_squared_error(y_true, y_pred):
#         return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1)) 

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))




def lr_scheduler(epoch, lr):
        if (epoch+1)%5==0:
                return lr * 0.4
        return lr


callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)



opt=keras.optimizers.Adam(lr=1e-3)


# opt=keras.optimizers.RMSprop(lr=4e-3,decay=0.95,momentum=0.9, epsilon=1e-8, name="RMSprop")

model.compile(loss = root_mean_squared_error,optimizer=opt , metrics=['mean_absolute_error'])
# model.compile(loss ='mean_absolute_error' ,optimizer='adam', metrics=['mean_absolute_error',root_mean_squared_error])
print(model.summary())



cp1= ModelCheckpoint(filepath="finalswap/save_best.h5", monitor='loss',save_best_only=True,verbose=1,mode='min',save_weights_only=True)
cp2= ModelCheckpoint(filepath='finalswap/save_all.h5', monitor='loss',save_best_only=False ,verbose=2,save_weights_only=True)

callbacks_list = [callback,cp1,cp2,csv_logger]






# model.fit(X_train,y_train, batch_size =1024, epochs = 1000, validation_split = 0.2,validation_data=(xval, yval))
# model.fit(x,y_train.values, batch_size =1024, epochs = 10,validation_data=(x_v,y_valid.values),shuffle=True,callbacks=[callbacks_list])
# model.fit(x_trn,y_train.values, batch_size =2048, epochs = 25 ,validation_data=(x_vld,y_valid.values))
model.fit(x_trn,y_train.values, batch_size =2048, epochs = 15,callbacks=callbacks_list)
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
# Out:
# [<tf.Tensor 'reshape_13/Reshape:0' shape=(None, 50) dtype=float32>, <tf.Tensor 'reshape_14/Reshape:0' shape=(None, 50) dtype=float32>, <tf.Tensor 'reshape_15/Reshape:0' shape=(None, 50) dtype=float32>, <tf.Tensor 'reshape_16/Reshape:0' shape=(None, 50) dtype=float32>, <tf.Tensor 'reshape_17/Reshape:0' shape=(None, 19) dtype=float32>, <tf.Tensor 'reshape_18/Reshape:0' shape=(None, 1) dtype=float32>, <tf.Tensor 'reshape_19/Reshape:0' shape=(None, 6) dtype=float32>, <tf.Tensor 'reshape_20/Reshape:0' shape=(None, 3) dtype=float32>, <tf.Tensor 'reshape_21/Reshape:0' shape=(None, 8) dtype=float32>, <tf.Tensor 'reshape_22/Reshape:0' shape=(None, 50) dtype=float32>, <tf.Tensor 'reshape_23/Reshape:0' shape=(None, 50) dtype=float32>, <tf.Tensor 'reshape_24/Reshape:0' shape=(None, 50) dtype=float32>]
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_19 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_21 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_22 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_23 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_24 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_13 (Embedding)        (None, 1, 50)        1109450     input_13[0][0]
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, 1, 50)        195850      input_14[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, 1, 50)        21850       input_15[0][0]
# __________________________________________________________________________________________________
# embedding_16 (Embedding)        (None, 1, 50)        218650      input_16[0][0]
# __________________________________________________________________________________________________
# embedding_17 (Embedding)        (None, 1, 19)        722         input_17[0][0]
# __________________________________________________________________________________________________
# embedding_18 (Embedding)        (None, 1, 1)         3           input_18[0][0]
# __________________________________________________________________________________________________
# embedding_19 (Embedding)        (None, 1, 6)         78          input_19[0][0]
# __________________________________________________________________________________________________
# embedding_20 (Embedding)        (None, 1, 3)         21          input_20[0][0]
# __________________________________________________________________________________________________
# embedding_21 (Embedding)        (None, 1, 8)         128         input_21[0][0]
# __________________________________________________________________________________________________
# embedding_22 (Embedding)        (None, 1, 50)        10000       input_22[0][0]
# __________________________________________________________________________________________________
# embedding_23 (Embedding)        (None, 1, 50)        23750       input_23[0][0]
# __________________________________________________________________________________________________
# embedding_24 (Embedding)        (None, 1, 50)        26800       input_24[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_13 (SpatialDr (None, 1, 50)        0           embedding_13[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_14 (SpatialDr (None, 1, 50)        0           embedding_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_15 (SpatialDr (None, 1, 50)        0           embedding_15[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_16 (SpatialDr (None, 1, 50)        0           embedding_16[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_17 (SpatialDr (None, 1, 19)        0           embedding_17[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_18 (SpatialDr (None, 1, 1)         0           embedding_18[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_19 (SpatialDr (None, 1, 6)         0           embedding_19[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_20 (SpatialDr (None, 1, 3)         0           embedding_20[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_21 (SpatialDr (None, 1, 8)         0           embedding_21[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_22 (SpatialDr (None, 1, 50)        0           embedding_22[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_23 (SpatialDr (None, 1, 50)        0           embedding_23[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_24 (SpatialDr (None, 1, 50)        0           embedding_24[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 50)           0           spatial_dropout1d_13[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 50)           0           spatial_dropout1d_14[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 50)           0           spatial_dropout1d_15[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 50)           0           spatial_dropout1d_16[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 19)           0           spatial_dropout1d_17[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 1)            0           spatial_dropout1d_18[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 6)            0           spatial_dropout1d_19[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 3)            0           spatial_dropout1d_20[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 8)            0           spatial_dropout1d_21[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 50)           0           spatial_dropout1d_22[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 50)           0           spatial_dropout1d_23[0][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 50)           0           spatial_dropout1d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 387)          0           reshape_13[0][0]
#                                                                  reshape_14[0][0]
#                                                                  reshape_15[0][0]
#                                                                  reshape_16[0][0]
#                                                                  reshape_17[0][0]
#                                                                  reshape_18[0][0]
#                                                                  reshape_19[0][0]
#                                                                  reshape_20[0][0]
#                                                                  reshape_21[0][0]
#                                                                  reshape_22[0][0]
#                                                                  reshape_23[0][0]
#                                                                  reshape_24[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 512)          198656      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 512)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 256)          131328      dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 256)          0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          32896       dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          16512       dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128)          0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           8256        dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64)           0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 16)           1040        dropout_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 16)           0           dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1)            17          dropout_12[0][0]
# ==================================================================================================
# Total params: 1,996,007
# Trainable params: 1,996,007
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# C:\Users\sKuma\anaconda3\envs\tf_4\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/15
#  16384/284778 [>.............................] - ETA: 28s - loss: 25.8024 - mean_absolute_error: 3.4174
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-1b5e8d48bee3> in <module>
#      78 # model.fit(x,y_train.values, batch_size =1024, epochs = 10,validation_data=(x_v,y_valid.values),shuffle=True,callbacks=[callbacks_list])
#      79 # model.fit(x_trn,y_train.values, batch_size =2048, epochs = 25 ,validation_data=(x_vld,y_valid.values))
# ---> 80 model.fit(x_trn,y_train.values, batch_size =2048, epochs = 15,callbacks=callbacks_list)
#      81 model_json = model.to_json()
#      82 with open("model.json", "w") as json_file:
#
# ~\anaconda3\envs\tf_4\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\anaconda3\envs\tf_4\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\anaconda3\envs\tf_4\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3738         value = math_ops.cast(value, tensor.dtype)
#    3739       converted_inputs.append(value)
# -> 3740     outputs = self._graph_fn(*converted_inputs)
#    3741
#    3742     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~\anaconda3\envs\tf_4\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1079       TypeError: For invalid positional/keyword argument combinations.
#    1080     """
# -> 1081     return self._call_impl(args, kwargs)
#    1082
#    1083   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~\anaconda3\envs\tf_4\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1119       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1120           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1121     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1122
#    1123   def _filtered_call(self, args, kwargs):
#
# ~\anaconda3\envs\tf_4\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~\anaconda3\envs\tf_4\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~\anaconda3\envs\tf_4\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
sub=model.predict(x_tst)
# model.predict(x_tst)

# %%
sub=pd.Series(sub.reshape(1,-1)[0],name='UnitPrice')

# %%
sub.var()

# %%
sub.to_csv('submission.csv',index=False)

# %%
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# %%
loaded_model.load_weights('model.h5')
# loaded_model.load_weights('finalswap/save_best.h5')

# %%
loaded_model.predict(x_tst)
# Out:
# array([[2.0208805],
#        [1.555449 ],
#        [3.5218606],
#        ...,
#        [1.7743297],
#        [3.4725018],
#        [4.0853477]], dtype=float32)
